# %%
import pandas as pd
from tsfresh.feature_extraction import MinimalFCParameters
from tsfresh.feature_extraction import extract_features
from tqdm import tqdm
tqdm.pandas() 
import numpy as np

# %%
settings = MinimalFCParameters()

# %%
path_processed_data = '../data/processed/'
path_interim_data = '../data/interim/'
model_name = 'facebook/fasttext-pt-vectors'
model_name = f'neuralmind/bert-base-portuguese-cased'
corpus = 'ig'
path_data = path_interim_data + f'train_r3_{corpus}_separated_comments_{model_name.replace('/', '_')}_part_1.parquet'

emb_dim = 300

# %%
data = pd.read_parquet(path_data)

# %%
data
# Out:
#        Polarity                                              Texts     emb_1  \
# 0       against  PQP ESSE DORAMA É MUITO FOADA(Sassy GoGo(Cheer... -0.028024
# 1       against  Caraleo só falta dois eps pra acabar, alguém j... -0.255375
# 2       against         @Rachingaio mt bom super recomendo a todos -0.003749
# 3       against        @Rachingaio por mais doramas como esse, obg -0.025635
# 4       against  @Rachingaio pra quem gosta de chorar super rec... -0.040909
# ...         ...                                                ...       ...
# 353388      for  tudo, TUDO eu me machuco.......... senhor até ...  0.145242
# 353389      for            @iamluquinha JURO, levo ate a amora cmg  0.051049
# 353390      for     @adamovich_igor @_annadenadai  kkk  ai meu pai  0.062123
# 353391      for  doida pra começar esse semestre com libras e p... -0.016453
# 353392      for  @mauricioszc__ vamo se comunicar só através de... -0.133800
#
#            emb_2     emb_3     emb_4     emb_5     emb_6     emb_7     emb_8  \
# 0      -0.098344  0.660402  0.043468  0.676496  0.442359  0.145548 -0.201438
# 1      -0.438047  0.094775 -0.053067  0.696640  0.295056 -0.222752 -0.126266
# 2      -0.474420  0.297793  0.038054  0.531625  0.311008  0.164886 -0.011964
# 3      -0.216783  0.401273  0.147795  0.528395  0.333482  0.211541 -0.057564
# 4      -0.122579  0.379697  0.145921  0.481259  0.553947  0.063625 -0.149979
# ...          ...       ...       ...       ...       ...       ...       ...
# 353388 -0.241835  0.304948  0.111270  0.580606  0.063885 -0.111339  0.066628
# 353389 -0.220019  0.344296 -0.047703  0.627780  0.487342 -0.121557 -0.090200
# 353390 -0.401959  0.607620 -0.095787  0.501202  0.353872 -0.056713 -0.113078
# 353391 -0.081163  0.273003 -0.152947  0.546173  0.501041 -0.027347  0.019948
# 353392 -0.387124  0.124822  0.029299  0.457467  0.200838  0.003071 -0.093018
#
#         ...   emb_759   emb_760   emb_761   emb_762   emb_763   emb_764  \
# 0       ... -0.148059  0.134793 -0.411078 -0.197732  0.443087 -0.405188
# 1       ...  0.066845  0.235846 -0.555240  0.145052  0.188692 -0.180088
# 2       ...  0.147495  0.084072 -0.571597 -0.036361  0.243968 -0.663591
# 3       ... -0.142705  0.194418 -0.599015 -0.380804  0.342691 -0.169013
# 4       ... -0.039032 -0.013972 -0.675362 -0.041098  0.319005 -0.350476
# ...     ...       ...       ...       ...       ...       ...       ...
# 353388  ... -0.229765  0.081686 -0.848792  0.028837  0.145200 -0.202544
# 353389  ... -0.089925 -0.084158 -0.742380 -0.250807  0.327169 -0.275111
# 353390  ... -0.261177 -0.003492 -0.762340 -0.221880  0.347396 -0.445986
# 353391  ...  0.081932 -0.036575 -0.585763 -0.385614  0.316500 -0.577458
# 353392  ... -0.124495 -0.213864 -0.561048 -0.232833  0.091312 -0.391827
#
#          emb_765   emb_766   emb_767   emb_768
# 0       0.174064  0.191733  0.039695 -0.324170
# 1      -0.116405 -0.052135 -0.034546 -0.146468
# 2       0.365365  0.093985 -0.118995 -0.286341
# 3       0.037395 -0.169477  0.046856 -0.206322
# 4      -0.054267  0.127987 -0.058664 -0.176111
# ...          ...       ...       ...       ...
# 353388  0.303871  0.578988 -0.027168 -0.071908
# 353389  0.016266 -0.242095 -0.042133 -0.282020
# 353390  0.256292 -0.024289  0.166744 -0.333771
# 353391  0.256011  0.250349 -0.128809 -0.306251
# 353392  0.078523 -0.147982 -0.061594 -0.222551
#
# [353393 rows x 770 columns]

# %%
data.head()
# Out:
#   Polarity                                              Texts     emb_1  \
# 0  against  PQP ESSE DORAMA É MUITO FOADA(Sassy GoGo(Cheer... -0.028024
# 1  against  Caraleo só falta dois eps pra acabar, alguém j... -0.255375
# 2  against         @Rachingaio mt bom super recomendo a todos -0.003749
# 3  against        @Rachingaio por mais doramas como esse, obg -0.025635
# 4  against  @Rachingaio pra quem gosta de chorar super rec... -0.040909
#
#       emb_2     emb_3     emb_4     emb_5     emb_6     emb_7     emb_8  ...  \
# 0 -0.098344  0.660402  0.043468  0.676496  0.442359  0.145548 -0.201438  ...
# 1 -0.438047  0.094775 -0.053067  0.696640  0.295056 -0.222752 -0.126266  ...
# 2 -0.474420  0.297793  0.038054  0.531625  0.311008  0.164886 -0.011964  ...
# 3 -0.216783  0.401273  0.147795  0.528395  0.333482  0.211541 -0.057564  ...
# 4 -0.122579  0.379697  0.145921  0.481259  0.553947  0.063625 -0.149979  ...
#
#     emb_759   emb_760   emb_761   emb_762   emb_763   emb_764   emb_765  \
# 0 -0.148059  0.134793 -0.411078 -0.197732  0.443087 -0.405188  0.174064
# 1  0.066845  0.235846 -0.555240  0.145052  0.188692 -0.180088 -0.116405
# 2  0.147495  0.084072 -0.571597 -0.036361  0.243968 -0.663591  0.365365
# 3 -0.142705  0.194418 -0.599015 -0.380804  0.342691 -0.169013  0.037395
# 4 -0.039032 -0.013972 -0.675362 -0.041098  0.319005 -0.350476 -0.054267
#
#     emb_766   emb_767   emb_768
# 0  0.191733  0.039695 -0.324170
# 1 -0.052135 -0.034546 -0.146468
# 2  0.093985 -0.118995 -0.286341
# 3 -0.169477  0.046856 -0.206322
# 4  0.127987 -0.058664 -0.176111
#
# [5 rows x 770 columns]

# %%
data_emb = data.drop(
    ['Texts', 'Polarity'],
    axis =1
)

# %%
data_emb.head()
# Out:
#       emb_1     emb_2     emb_3     emb_4     emb_5     emb_6     emb_7  \
# 0 -0.028024 -0.098344  0.660402  0.043468  0.676496  0.442359  0.145548
# 1 -0.255375 -0.438047  0.094775 -0.053067  0.696640  0.295056 -0.222752
# 2 -0.003749 -0.474420  0.297793  0.038054  0.531625  0.311008  0.164886
# 3 -0.025635 -0.216783  0.401273  0.147795  0.528395  0.333482  0.211541
# 4 -0.040909 -0.122579  0.379697  0.145921  0.481259  0.553947  0.063625
#
#       emb_8     emb_9    emb_10  ...   emb_759   emb_760   emb_761   emb_762  \
# 0 -0.201438  0.365420 -0.187529  ... -0.148059  0.134793 -0.411078 -0.197732
# 1 -0.126266  0.236577 -0.661531  ...  0.066845  0.235846 -0.555240  0.145052
# 2 -0.011964  0.234516 -0.250827  ...  0.147495  0.084072 -0.571597 -0.036361
# 3 -0.057564  0.166785 -0.323500  ... -0.142705  0.194418 -0.599015 -0.380804
# 4 -0.149979  0.091121 -0.381520  ... -0.039032 -0.013972 -0.675362 -0.041098
#
#     emb_763   emb_764   emb_765   emb_766   emb_767   emb_768
# 0  0.443087 -0.405188  0.174064  0.191733  0.039695 -0.324170
# 1  0.188692 -0.180088 -0.116405 -0.052135 -0.034546 -0.146468
# 2  0.243968 -0.663591  0.365365  0.093985 -0.118995 -0.286341
# 3  0.342691 -0.169013  0.037395 -0.169477  0.046856 -0.206322
# 4  0.319005 -0.350476 -0.054267  0.127987 -0.058664 -0.176111
#
# [5 rows x 768 columns]

# %%
X_tsfresh = extract_features(
    data_emb,
    column_id='User_ID',
    default_fc_parameters= settings
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 X_tsfresh = extract_features(
#       2     data_emb,
#       3     column_id='User_ID',
#       4     default_fc_parameters= settings
#       5 )
#
# File ~/anaconda3/envs/env-stance-pred/lib/python3.12/site-packages/tsfresh/feature_extraction/extraction.py:164, in extract_features(timeseries_container, default_fc_parameters, kind_to_fc_parameters, column_id, column_sort, column_kind, column_value, chunksize, n_jobs, show_warnings, disable_progressbar, impute_function, profile, profiling_filename, profiling_sorting, distributor, pivot)
#     161 else:
#     162     warnings.simplefilter("default")
# --> 164 result = _do_extraction(
#     165     df=timeseries_container,
#     166     column_id=column_id,
#     167     column_value=column_value,
#     168     column_kind=column_kind,
#     169     column_sort=column_sort,
#     170     n_jobs=n_jobs,
#     171     chunk_size=chunksize,
#     172     disable_progressbar=disable_progressbar,
#     173     show_warnings=show_warnings,
#     174     default_fc_parameters=default_fc_parameters,
#     175     kind_to_fc_parameters=kind_to_fc_parameters,
#     176     distributor=distributor,
#     177     pivot=pivot,
#     178 )
#     180 # Impute the result if requested
#     181 if impute_function is not None:
#
# File ~/anaconda3/envs/env-stance-pred/lib/python3.12/site-packages/tsfresh/feature_extraction/extraction.py:260, in _do_extraction(df, column_id, column_value, column_kind, column_sort, default_fc_parameters, kind_to_fc_parameters, n_jobs, chunk_size, disable_progressbar, show_warnings, distributor, pivot)
#     193 def _do_extraction(
#     194     df,
#     195     column_id,
#    (...)
#     206     pivot,
#     207 ):
#     208     """
#     209     Wrapper around the _do_extraction_on_chunk, which calls it on all chunks in the data frame.
#     210     A chunk is a subset of the data, with a given kind and id - so a single time series.
#    (...)
#     257     :rtype: pd.DataFrame
#     258     """
# --> 260     data = to_tsdata(df, column_id, column_kind, column_value, column_sort)
#     262     if distributor is None:
#     263         if isinstance(data, Iterable):
#
# File ~/anaconda3/envs/env-stance-pred/lib/python3.12/site-packages/tsfresh/feature_extraction/data.py:478, in to_tsdata(df, column_id, column_kind, column_value, column_sort)
#     476             return WideTsFrameAdapter(df, column_id, column_sort, [column_value])
#     477         else:
# --> 478             return WideTsFrameAdapter(df, column_id, column_sort)
#     480 elif isinstance(df, dict):
#     481     return TsDictAdapter(df, column_id, column_value, column_sort)
#
# File ~/anaconda3/envs/env-stance-pred/lib/python3.12/site-packages/tsfresh/feature_extraction/data.py:181, in WideTsFrameAdapter.__init__(self, df, column_id, column_sort, value_columns)
#     178 if column_id is None:
#     179     raise ValueError("A value for column_id needs to be supplied")
# --> 181 _check_nan(df, column_id)
#     183 if not value_columns:
#     184     value_columns = _get_value_columns(df, column_id, column_sort)
#
# File ~/anaconda3/envs/env-stance-pred/lib/python3.12/site-packages/tsfresh/feature_extraction/data.py:142, in _check_nan(df, *columns)
#     140 for col in columns:
#     141     if col not in df.columns:
# --> 142         raise ValueError("Column not found: {}".format(col))
#     144     if df[col].isnull().any():
#     145         raise ValueError("Column must not contain NaN values: {}".format(col))
#
# ValueError: Column not found: User_ID

# %%
X_tsfresh.head()
# Out:
#             emb_0__sum_values  emb_0__median  emb_0__mean  emb_0__length  \
# r2_ig_1             18.705984       0.016341     0.021305          878.0
# r2_ig_10            -0.694554      -0.007306    -0.007632           91.0
# r2_ig_100          134.651776       0.021312     0.026844         5016.0
# r2_ig_1003           8.989551       0.004784     0.007261         1238.0
# r2_ig_1005          -0.023906      -0.023906    -0.023906            1.0
#
#             emb_0__standard_deviation  emb_0__variance  \
# r2_ig_1                      0.034774         0.001209
# r2_ig_10                     0.025381         0.000644
# r2_ig_100                    0.034851         0.001215
# r2_ig_1003                   0.029329         0.000860
# r2_ig_1005                   0.000000         0.000000
#
#             emb_0__root_mean_square  emb_0__maximum  emb_0__absolute_maximum  \
# r2_ig_1                    0.040782        0.161842                 0.161842
# r2_ig_10                   0.026504        0.077938                 0.094406
# r2_ig_100                  0.043991        0.277412                 0.277412
# r2_ig_1003                 0.030214        0.167369                 0.167369
# r2_ig_1005                 0.023906       -0.023906                 0.023906
#
#             emb_0__minimum  ...  emb_299__sum_values  emb_299__median  \
# r2_ig_1          -0.108997  ...            16.013355         0.023159
# r2_ig_10         -0.094406  ...             0.254780        -0.000196
# r2_ig_100        -0.264804  ...           214.679097         0.046704
# r2_ig_1003       -0.089634  ...             5.541268         0.009481
# r2_ig_1005       -0.023906  ...             0.385951         0.385951
#
#             emb_299__mean  emb_299__length  emb_299__standard_deviation  \
# r2_ig_1          0.018238            878.0                     0.061676
# r2_ig_10         0.002800             91.0                     0.063650
# r2_ig_100        0.042799           5016.0                     0.063111
# r2_ig_1003       0.004476           1238.0                     0.060376
# r2_ig_1005       0.385951              1.0                     0.000000
#
#             emb_299__variance  emb_299__root_mean_square  emb_299__maximum  \
# r2_ig_1              0.003804                   0.064316          0.221551
# r2_ig_10             0.004051                   0.063712          0.140630
# r2_ig_100            0.003983                   0.076254          0.236323
# r2_ig_1003           0.003645                   0.060541          0.163734
# r2_ig_1005           0.000000                   0.385951          0.385951
#
#             emb_299__absolute_maximum  emb_299__minimum
# r2_ig_1                      0.222580         -0.222580
# r2_ig_10                     0.245795         -0.245795
# r2_ig_100                    0.331171         -0.331171
# r2_ig_1003                   0.239796         -0.239796
# r2_ig_1005                   0.385951          0.385951
#
# [5 rows x 3000 columns]

# %%
X_tsfresh.shape
# Out:
# (1796, 3000)

# %%
X_tsfresh_cplt = X_tsfresh.reset_index(drop=False).rename(columns={'index': 'User_ID'}).merge(
    data[['User_ID','Polarity']].drop_duplicates(),
    on = 'User_ID',
    how = 'left'
)

# %%
path_output = path_processed_data + f'train_r3_{corpus}_separated_comments_{model_name.replace("/", "_")}_tsfresh.parquet'

X_tsfresh_cplt.to_parquet(path_output,index = False)
